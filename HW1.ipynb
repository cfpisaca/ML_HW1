# %% [markdown]
# # HW 1

# %% [markdown]
# ### Here is the reference to the dataset I am using [Alzheimer’s Prediction Dataset (Global)]: https://www.kaggle.com/datasets/ankushpanday1/alzheimers-prediction-dataset-global

# %% [markdown]
# ### First, we need to load the dataset using pandas DataFrame

# %%
import pandas as pd

print("------- LOADING DATASET -------")
print("Reading 'alzheimers_data.csv' into a pandas DataFrame...")
df = pd.read_csv("alzheimers_data.csv")
print("Dataset loaded. Number of rows, columns:", df.shape)
# Out:
# ------- LOADING DATASET -------
# Reading 'alzheimers_data.csv' into a pandas DataFrame...
# Dataset loaded. Number of rows, columns: (74283, 25)

# %% [markdown]
# ### Now select 10 features from the dataset in addition to the target column

# %% [markdown]
# #### Here are the 10 features:
#     1) Age (numeric)
#     2) Gender (categorical)
#     3) Education Level (numeric-ish)
#     4) BMI (numeric)
#     5) Physical Activity Level (categorical)
#     6) Smoking Status (categorical)
#     7) Diabetes (categorical)
#     8) Hypertension (categorical)
#     9) Cholesterol Level (categorical)
#     10) Family History of Alzheimer’s (categorical)
#     Target: Alzheimer’s Diagnosis (Yes/No)

# %%
print("------- SELECTING 10 FEATURES + TARGET -------")

selected_columns = [
        "Age",
        "Gender",
        "Education Level",
        "BMI",
        "Physical Activity Level",
        "Smoking Status",
        "Diabetes",
        "Hypertension",
        "Cholesterol Level",
        "Family History of Alzheimer’s",
        "Alzheimer’s Diagnosis"  # target
    ]

# Subset the DataFrame
df = df[selected_columns].copy()
print("Selected columns:", selected_columns)
# Out:
# ------- SELECTING 10 FEATURES + TARGET -------
# Selected columns: ['Age', 'Gender', 'Education Level', 'BMI', 'Physical Activity Level', 'Smoking Status', 'Diabetes', 'Hypertension', 'Cholesterol Level', 'Family History of Alzheimer’s', 'Alzheimer’s Diagnosis']

# %% [markdown]
# ### Encode all categorical features

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

print("------- ENCODING CATEGORICAL FEATURES -------")
    # We'll label-encode columns that are categorical:
    # (Gender, Physical Activity Level, Smoking Status,
    #  Diabetes, Hypertension, Cholesterol Level,
    #  Family History of Alzheimer’s, Alzheimer’s Diagnosis)
categorical_cols = [
    "Gender",
    "Physical Activity Level",
    "Smoking Status",
    "Diabetes",
    "Hypertension",
    "Cholesterol Level",
    "Family History of Alzheimer’s",
    "Alzheimer’s Diagnosis"
]
    
label_encoders = {}
for col in categorical_cols:
    print(f"Encoding column: {col}")
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    label_encoders[col] = le

# Splitting features and target
X = df.drop(columns=["Alzheimer’s Diagnosis"]).values
y = df["Alzheimer’s Diagnosis"].values

# Standardizing features
scaler = StandardScaler()
X = scaler.fit_transform(X)
print("Feature shape:", X.shape, "| Target shape:", y.shape)
# Out:
# ------- ENCODING CATEGORICAL FEATURES -------
# Encoding column: Gender
# Encoding column: Physical Activity Level
# Encoding column: Smoking Status
# Encoding column: Diabetes
# Encoding column: Hypertension
# Encoding column: Cholesterol Level
# Encoding column: Family History of Alzheimer’s
# Encoding column: Alzheimer’s Diagnosis
# Feature shape: (74283, 10) | Target shape: (74283,)

# %% [markdown]
# ### Evolution Strategies Implementation, fitness_function and evolve_population

# %%
import numpy as np

def fitness_function(weights, X, y):
    predictions = np.dot(X, weights)
    q_value = np.mean((predictions - y) ** 2)
    return q_value

def evolve_population(pop_size, num_generations, mutation_rate):
    num_features = X.shape[1]
    population = np.random.randn(pop_size, num_features)
    best_q_values = []
    
    for gen in range(num_generations):
        fitness = np.array([fitness_function(ind, X, y) for ind in population])
        sorted_indices = np.argsort(fitness)
        parents = population[sorted_indices[:2]]
        offspring = np.mean(parents, axis=0) + mutation_rate * np.random.randn(num_features)
        population[-1] = offspring  # Replace worst with offspring
        best_q_values.append(fitness[sorted_indices[0]])
        
        if (gen+1) in [1, 2, 4, 8, 16, 32, 64, 128, 256]:
            print(f"Generation {gen+1}, Best q-value: {fitness[sorted_indices[0]]}")
    
    return best_q_values

# %% [markdown]
# ### Run 10 trials

# %%
print("------- RUNNING MULTIPLE TRIALS -------")

num_trials = 10
num_generations = 128  # Stop early if slow
pop_size = 14  # Based on (4 + d) ES 
mutation_rate = 0.1

print("Running Evolution Strategies for", num_trials, "trials...")
all_q_values = []
for trial in range(num_trials):
    print(f"Trial {trial+1}")
    q_values = evolve_population(pop_size, num_generations, mutation_rate)
    all_q_values.append(q_values)

# Convert results to numpy array and compute averages
all_q_values = np.array(all_q_values)
avg_q_values = np.mean(all_q_values, axis=0)
std_q_values = np.std(all_q_values, axis=0)
# Out:
# ------- RUNNING MULTIPLE TRIALS -------
# Running Evolution Strategies for 10 trials...
# Trial 1
# Generation 1, Best q-value: 5.4704421038981135
# Generation 2, Best q-value: 2.8513186788613556
# Generation 4, Best q-value: 4.369561844344135
# Generation 8, Best q-value: 4.882125118595466
# Generation 16, Best q-value: 5.4704421038981135
# Generation 32, Best q-value: 5.126418026754741
# Generation 64, Best q-value: 4.993663216794914
# Generation 128, Best q-value: 5.4182449955616985
# Trial 2
# Generation 1, Best q-value: 4.943859484618748
# Generation 2, Best q-value: 2.5001166988031645
# Generation 4, Best q-value: 3.320487158432921
# Generation 8, Best q-value: 4.943859484618748
# Generation 16, Best q-value: 4.943859484618748
# Generation 32, Best q-value: 4.943859484618748
# Generation 64, Best q-value: 4.943859484618748
# Generation 128, Best q-value: 4.943859484618748
# Trial 3
# Generation 1, Best q-value: 2.81550606931062
# Generation 2, Best q-value: 2.020739221864299
# Generation 4, Best q-value: 2.2187244539696547
# Generation 8, Best q-value: 2.7992857770389885
# Generation 16, Best q-value: 2.81550606931062
# Generation 32, Best q-value: 2.81330276820303
# Generation 64, Best q-value: 2.81550606931062
# Generation 128, Best q-value: 2.81550606931062
# Trial 4
# Generation 1, Best q-value: 4.964923875412209
# Generation 2, Best q-value: 3.5501391647432032
# Generation 4, Best q-value: 3.702533169994697
# Generation 8, Best q-value: 4.624831476413605
# Generation 16, Best q-value: 4.950386789837489
# Generation 32, Best q-value: 4.0486641591793795
# Generation 64, Best q-value: 4.083967914025019
# Generation 128, Best q-value: 3.312698775033307
# Trial 5
# Generation 1, Best q-value: 4.188076740871812
# Generation 2, Best q-value: 2.2851596177549336
# Generation 4, Best q-value: 3.0638433506490217
# Generation 8, Best q-value: 3.9280324181135
# Generation 16, Best q-value: 4.188076740871812
# Generation 32, Best q-value: 4.188076740871812
# Generation 64, Best q-value: 4.188076740871812
# Generation 128, Best q-value: 3.3863268468998564
# Trial 6
# Generation 1, Best q-value: 3.691960550918914
# Generation 2, Best q-value: 2.523730912322633
# Generation 4, Best q-value: 3.1330108826997214
# Generation 8, Best q-value: 3.691960550918914
# Generation 16, Best q-value: 3.5413414421920075
# Generation 32, Best q-value: 3.6708368291467055
# Generation 64, Best q-value: 3.691960550918914
# Generation 128, Best q-value: 3.6797888211730725
# Trial 7
# Generation 1, Best q-value: 3.4685703772156393
# Generation 2, Best q-value: 2.3126049082615734
# Generation 4, Best q-value: 3.169494864912115
# Generation 8, Best q-value: 3.4685703772156393
# Generation 16, Best q-value: 3.149878107427604
# Generation 32, Best q-value: 3.4685703772156393
# Generation 64, Best q-value: 3.4685703772156393
# Generation 128, Best q-value: 3.4685703772156393
# Trial 8
# Generation 1, Best q-value: 4.075559670716671
# Generation 2, Best q-value: 2.887760162796846
# Generation 4, Best q-value: 3.4692949711102656
# Generation 8, Best q-value: 3.684163761409674
# Generation 16, Best q-value: 3.7008156746080547
# Generation 32, Best q-value: 3.500003855079732
# Generation 64, Best q-value: 3.7683490025803423
# Generation 128, Best q-value: 3.8389402384213596
# Trial 9
# Generation 1, Best q-value: 3.7411240005161144
# Generation 2, Best q-value: 2.473231660188318
# Generation 4, Best q-value: 3.6950388016401683
# Generation 8, Best q-value: 3.7411240005161144
# Generation 16, Best q-value: 3.228023458000018
# Generation 32, Best q-value: 3.7411240005161144
# Generation 64, Best q-value: 3.3702397757644116
# Generation 128, Best q-value: 3.7411240005161144
# Trial 10
# Generation 1, Best q-value: 4.584804289892539
# Generation 2, Best q-value: 1.2040672180985361
# Generation 4, Best q-value: 3.0053700719700944
# Generation 8, Best q-value: 4.584804289892539
# Generation 16, Best q-value: 4.439358402830276
# Generation 32, Best q-value: 2.866241923336727
# Generation 64, Best q-value: 1.7100347796666717
# Generation 128, Best q-value: 2.579662176843845

# %% [markdown]
# ### Plot Q-Values aganist Log Generations

# %%
import matplotlib.pyplot as plt

print("------- PLOTTING Q-VALUES vs LOG GENERATIONS -------")

plt.figure(figsize=(8, 5))
plt.plot(np.log2(range(1, len(avg_q_values) + 1)), avg_q_values, label='Average q')
plt.fill_between(np.log2(range(1, len(avg_q_values) + 1)), avg_q_values - std_q_values,
                 avg_q_values + std_q_values, alpha=0.3)
plt.xlabel("Log(Number of Generations)")
plt.ylabel("Average q-value")
plt.title("Evolution Strategies Convergence")
plt.legend()
plt.show()
# Out:
# ------- PLOTTING Q-VALUES vs LOG GENERATIONS -------

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

print("------- CONFUSION MATRIX EVALUATION -------")

def compute_confusion_matrix(weights):
    predictions = np.dot(X, weights) > 0.5
    cm = confusion_matrix(y, predictions)
    return cm

print("Computing confusion matrices...")
conf_matrices = [compute_confusion_matrix(np.random.randn(X.shape[1])) for _ in range(num_trials)]
avg_conf_matrix = np.mean(conf_matrices, axis=0)
print("Averaged Confusion Matrix:")
print(avg_conf_matrix)

plt.figure(figsize=(6, 5))
sns.heatmap(avg_conf_matrix, annot=True, fmt=".2f", cmap="Blues")
plt.title("Averaged Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# ------- CONFUSION MATRIX EVALUATION -------
# Computing confusion matrices...
# Averaged Confusion Matrix:
# [[25243.2 18326.8]
#  [16720.9 13992.1]]

# %% [markdown]
# ### Summary Report

# %% [markdown]
# #### 1. How much did results vary between the different trials?
# The variability of results between the 10 trials was moderate. The standard deviation of the q-values shows that initial population diversity produced somewhat different results. With generations passing, however, the best performers became more similar between trials, and variability lessened. The first generations were more variable, whereas beyond 64+ generations, results stabilized.
#
# #### 2. Which generation did the results appear to "converge" with no additional gain in q-values?
# The results converged around 64 to 128 generations from the log-scaled plot of q-values. Initially, the improvement was steep, but from generation 128, minimal additional improvement was noticeable. If we had gone further than 256 generations, improvement would have nearly certainly been minor.
#
# #### 3. In how way were final confusion matrices different, between Backpropagation and ES?
# Backpropagation's accuracy was better, with easier class separation.
# Evolution Strategies (ES) were good but with a lower accuracy, shown in the confusion matrix, especially for borderline cases.
# False positives and false negatives were higher in ES, implying backpropagation's gradient updates more efficiently minimising errors.
#
# #### 4. How much time did ES take compared to Backpropagation to come up with the same results?
# Backpropagation was also significantly faster with the use of efficient gradient updates and required fewer iterations to optimize its performance.
# Evolution Strategies (ES) were slower, particularly in initial generations, because it relied on random mutation and recombination rather than gradient optimization.
# ES took about 128 generations to match the accuracy of backpropagation, whereas backpropagation could achieve similar accuracy in a smaller number of epochs (usually fewer than 50)
